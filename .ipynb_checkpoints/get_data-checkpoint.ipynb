# %%
# !pip install nba_api
# Out:
# Collecting nba_api
#   Downloading nba_api-1.1.8-py3-none-any.whl (217 kB)
#      |████████████████████████████████| 217 kB 492 kB/s eta 0:00:01
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.7/site-packages (from nba_api) (2.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests->nba_api) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests->nba_api) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests->nba_api) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests->nba_api) (2019.11.28)
# Installing collected packages: nba-api
# Successfully installed nba-api-1.1.8

# %%
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder

import pandas as pd
import sqlite3

# %%
team_data=teams.get_teams()

# %%
connection = sqlite3.connect('data/nba.db')

# %%
for t in team_data:
    gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=t['id'])
    games = gamefinder.get_data_frames()[0]
    games['opponent']=games.MATCHUP.apply(lambda x: x[-3:])#x.split(' @ '))
    games.to_sql(t['abbreviation'], connection, if_exists='replace')

# %%
pd.read_sql('''
SELECT 
*
FROM sqlite_master 
where type='table'
''', connection)
# Out:
#      type        name    tbl_name  rootpage  \
# 0   table  BOS-target  BOS-target      3783
# 1   table  CLE-target  CLE-target      3917
# 2   table  NOP-target  NOP-target      4051
# 3   table  CHI-target  CHI-target      4120
# 4   table  DAL-target  DAL-target      4251
# 5   table  DEN-target  DEN-target      4382
# 6   table  GSW-target  GSW-target      4509
# 7   table  HOU-target  HOU-target      4642
# 8   table  LAC-target  LAC-target      4773
# 9   table  LAL-target  LAL-target      4902
# 10  table  MIA-target  MIA-target      5041
# 11  table  MIL-target  MIL-target      5153
# 12  table  MIN-target  MIN-target      5281
# 13  table  BKN-target  BKN-target      5391
# 14  table  NYK-target  NYK-target      5518
# 15  table  ORL-target  ORL-target      5647
# 16  table  IND-target  IND-target      5752
# 17  table  PHI-target  PHI-target      5881
# 18  table  PHX-target  PHX-target      6011
# 19  table  POR-target  POR-target      6138
# 20  table  SAC-target  SAC-target      6273
# 21  table  SAS-target  SAS-target      6399
# 22  table  OKC-target  OKC-target      6535
# 23  table  TOR-target  TOR-target      6669
# 24  table  UTA-target  UTA-target      6760
# 25  table  MEM-target  MEM-target      6888
# 26  table  WAS-target  WAS-target      6977
# 27  table  DET-target  DET-target      7103
# 28  table  CHA-target  CHA-target      7236
# 29  table  ATL-target  ATL-target      3658
# 30  table         ATL         ATL        89
# 31  table         BOS         BOS       214
# 32  table         CLE         CLE       346
# 33  table         NOP         NOP       477
# 34  table         CHI         CHI       545
# 35  table         DAL         DAL       674
# 36  table         DEN         DEN       806
# 37  table         GSW         GSW       931
# 38  table         HOU         HOU      1064
# 39  table         LAC         LAC      1195
# 40  table         LAL         LAL      1322
# 41  table         MIA         MIA      1460
# 42  table         MIL         MIL      1573
# 43  table         MIN         MIN      1700
# 44  table         BKN         BKN      1810
# 45  table         NYK         NYK      1935
# 46  table         ORL         ORL      2063
# 47  table         IND         IND      2168
# 48  table         PHI         PHI      2296
# 49  table         PHX         PHX      2425
# 50  table         POR         POR      2551
# 51  table         SAC         SAC      2686
# 52  table         SAS         SAS      2811
# 53  table         OKC         OKC      2947
# 54  table         TOR         TOR         2
# 55  table         UTA         UTA      3083
# 56  table         MEM         MEM      3208
# 57  table         WAS         WAS      3296
# 58  table         DET         DET      3422
# 59  table         CHA         CHA      3554
#
#                                                   sql
# 0   CREATE TABLE "BOS-target" (\n"index" INTEGER,\...
# 1   CREATE TABLE "CLE-target" (\n"index" INTEGER,\...
# 2   CREATE TABLE "NOP-target" (\n"index" INTEGER,\...
# 3   CREATE TABLE "CHI-target" (\n"index" INTEGER,\...
# 4   CREATE TABLE "DAL-target" (\n"index" INTEGER,\...
# 5   CREATE TABLE "DEN-target" (\n"index" INTEGER,\...
# 6   CREATE TABLE "GSW-target" (\n"index" INTEGER,\...
# 7   CREATE TABLE "HOU-target" (\n"index" INTEGER,\...
# 8   CREATE TABLE "LAC-target" (\n"index" INTEGER,\...
# 9   CREATE TABLE "LAL-target" (\n"index" INTEGER,\...
# 10  CREATE TABLE "MIA-target" (\n"index" INTEGER,\...
# 11  CREATE TABLE "MIL-target" (\n"index" INTEGER,\...
# 12  CREATE TABLE "MIN-target" (\n"index" INTEGER,\...
# 13  CREATE TABLE "BKN-target" (\n"index" INTEGER,\...
# 14  CREATE TABLE "NYK-target" (\n"index" INTEGER,\...
# 15  CREATE TABLE "ORL-target" (\n"index" INTEGER,\...
# 16  CREATE TABLE "IND-target" (\n"index" INTEGER,\...
# 17  CREATE TABLE "PHI-target" (\n"index" INTEGER,\...
# 18  CREATE TABLE "PHX-target" (\n"index" INTEGER,\...
# 19  CREATE TABLE "POR-target" (\n"index" INTEGER,\...
# 20  CREATE TABLE "SAC-target" (\n"index" INTEGER,\...
# 21  CREATE TABLE "SAS-target" (\n"index" INTEGER,\...
# 22  CREATE TABLE "OKC-target" (\n"index" INTEGER,\...
# 23  CREATE TABLE "TOR-target" (\n"index" INTEGER,\...
# 24  CREATE TABLE "UTA-target" (\n"index" INTEGER,\...
# 25  CREATE TABLE "MEM-target" (\n"index" INTEGER,\...
# 26  CREATE TABLE "WAS-target" (\n"index" INTEGER,\...
# 27  CREATE TABLE "DET-target" (\n"index" INTEGER,\...
# 28  CREATE TABLE "CHA-target" (\n"index" INTEGER,\...
# 29  CREATE TABLE "ATL-target" (\n"index" INTEGER,\...
# 30  CREATE TABLE "ATL" (\n"index" INTEGER,\n  "SEA...
# 31  CREATE TABLE "BOS" (\n"index" INTEGER,\n  "SEA...
# 32  CREATE TABLE "CLE" (\n"index" INTEGER,\n  "SEA...
# 33  CREATE TABLE "NOP" (\n"index" INTEGER,\n  "SEA...
# 34  CREATE TABLE "CHI" (\n"index" INTEGER,\n  "SEA...
# 35  CREATE TABLE "DAL" (\n"index" INTEGER,\n  "SEA...
# 36  CREATE TABLE "DEN" (\n"index" INTEGER,\n  "SEA...
# 37  CREATE TABLE "GSW" (\n"index" INTEGER,\n  "SEA...
# 38  CREATE TABLE "HOU" (\n"index" INTEGER,\n  "SEA...
# 39  CREATE TABLE "LAC" (\n"index" INTEGER,\n  "SEA...
# 40  CREATE TABLE "LAL" (\n"index" INTEGER,\n  "SEA...
# 41  CREATE TABLE "MIA" (\n"index" INTEGER,\n  "SEA...
# 42  CREATE TABLE "MIL" (\n"index" INTEGER,\n  "SEA...
# 43  CREATE TABLE "MIN" (\n"index" INTEGER,\n  "SEA...
# 44  CREATE TABLE "BKN" (\n"index" INTEGER,\n  "SEA...
# 45  CREATE TABLE "NYK" (\n"index" INTEGER,\n  "SEA...
# 46  CREATE TABLE "ORL" (\n"index" INTEGER,\n  "SEA...
# 47  CREATE TABLE "IND" (\n"index" INTEGER,\n  "SEA...
# 48  CREATE TABLE "PHI" (\n"index" INTEGER,\n  "SEA...
# 49  CREATE TABLE "PHX" (\n"index" INTEGER,\n  "SEA...
# 50  CREATE TABLE "POR" (\n"index" INTEGER,\n  "SEA...
# 51  CREATE TABLE "SAC" (\n"index" INTEGER,\n  "SEA...
# 52  CREATE TABLE "SAS" (\n"index" INTEGER,\n  "SEA...
# 53  CREATE TABLE "OKC" (\n"index" INTEGER,\n  "SEA...
# 54  CREATE TABLE "TOR" (\n"index" INTEGER,\n  "SEA...
# 55  CREATE TABLE "UTA" (\n"index" INTEGER,\n  "SEA...
# 56  CREATE TABLE "MEM" (\n"index" INTEGER,\n  "SEA...
# 57  CREATE TABLE "WAS" (\n"index" INTEGER,\n  "SEA...
# 58  CREATE TABLE "DET" (\n"index" INTEGER,\n  "SEA...
# 59  CREATE TABLE "CHA" (\n"index" INTEGER,\n  "SEA...

# %%
pd.read_sql("select * from sas", connection)
# Out:
#       index SEASON_ID     TEAM_ID TEAM_ABBREVIATION          TEAM_NAME  \
# 0         0     22019  1610612759               SAS  San Antonio Spurs
# 1         1     22019  1610612759               SAS  San Antonio Spurs
# 2         2     22019  1610612759               SAS  San Antonio Spurs
# 3         3     22019  1610612759               SAS  San Antonio Spurs
# 4         4     22019  1610612759               SAS  San Antonio Spurs
# ...     ...       ...         ...               ...                ...
# 3496   3496     21983  1610612759               SAN  San Antonio Spurs
# 3497   3497     21983  1610612759               SAN  San Antonio Spurs
# 3498   3498     21983  1610612759               SAN  San Antonio Spurs
# 3499   3499     21983  1610612759               SAN  San Antonio Spurs
# 3500   3500     21983  1610612759               SAN  San Antonio Spurs
#
#          GAME_ID   GAME_DATE      MATCHUP WL  MIN  ...  OREB  DREB  REB  AST  \
# 0     0021901314  2020-08-13    SAS @ UTA  L  239  ...     9    35   44   24
# 1     0021901298  2020-08-11  SAS vs. HOU  W  240  ...     9    50   59   28
# 2     0021901287  2020-08-09    SAS @ NOP  W  241  ...    15    36   51   22
# 3     0021901274  2020-08-07  SAS vs. UTA  W  240  ...     8    39   47   27
# 4     0021901264  2020-08-05  SAS vs. DEN  L  239  ...    10    25   35   29
# ...          ...         ...          ... ..  ...  ...   ...   ...  ...  ...
# 3496  0028300051  1983-11-05    SAN @ UTH  L  240  ...    18    31   49   28
# 3497  0028300038  1983-11-03    SAN @ PHX  L  240  ...    12    25   37   13
# 3498  0028300028  1983-11-01  SAN vs. POR  L  240  ...    10    27   37   35
# 3499  0028300020  1983-10-30  SAN vs. DAL  W  240  ...    13    33   46   36
# 3500  0028300015  1983-10-29    SAN @ HOU  L  240  ...    11    30   41   21
#
#       STL  BLK  TOV  PF  PLUS_MINUS  opponent
# 0       4    8   15  20        -6.0       UTA
# 1      10    5   22  20        18.0       HOU
# 2      12    6   17  27         9.0       NOP
# 3      10    5   13  18         8.0       UTA
# 4      10    5    7  20        -6.0       DEN
# ...   ...  ...  ...  ..         ...       ...
# 3496    8    8   19  35         NaN       UTH
# 3497    6    2   27  35         NaN       PHX
# 3498    8   10   15  22         NaN       POR
# 3499   15   10   19  24         NaN       DAL
# 3500    9    6   21  22         NaN       HOU
#
# [3501 rows x 30 columns]

# %%
connection.close()
